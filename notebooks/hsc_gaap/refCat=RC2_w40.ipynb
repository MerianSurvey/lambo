# %%
import numpy as np
import time
import matplotlib
import matplotlib.pyplot as plt
import lsst.meas.base
import lsst.pex.config
import lsst.afw.display as afwDisplay
import lsst.afw.geom as afwGeom
import lsst.afw.table
import lsst.meas.algorithms
import lsst.meas.deblender
import lsst.pex.exceptions
import lsst.meas.extensions.gaap

from kuaizi.display import display_single
from astropy.io import fits
from astropy.table import Table, hstack

# %% [markdown]
# ## Try gaap with reference catalog

# %%
# Load Merian catalog as reference
filt = 'i'
tract = 9813
patch = 23
patch_old = f'{patch % 9},{patch // 9}'

import lsst.daf.butler as dafButler
butler = dafButler.Butler('/projects/MERIAN/repo/')
dataId = dict(tract=tract, patch=patch, band=filt)

refCat = butler.get(
    'deepCoadd_forced_src',
    collections='DECam/runs/merian/dr1_wide',
    dataId=dataId,
    instrument='DECam',
    skymap='hsc_rings_v1',
)[:10]#[0:8358:8357]

refExposure = butler.get(
    'deepCoadd_calexp',
    collections='DECam/runs/merian/dr1_wide',
    dataId=dataId,
    instrument='DECam',
    skymap='hsc_rings_v1',
)

refCatInBand = butler.get(
    'deepCoadd_ref',
    collections='DECam/runs/merian/dr1_wide',
    dataId=dataId,
    instrument='DECam',
    skymap='hsc_rings_v1',
)[:10]#[0:8358:8357]

# refCatInBand = lsst.afw.table.SourceCatalog.readFits(
#     '/projects/MERIAN/repo/S20A/deepCoadd_calexp/9813/5,3/deblendedFlux-HSC-G-9813-5,3.fits')

expID = dict(tract=tract, patch=patch, band=filt, skymap='hsc_rings_v1')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       8 butler = dafButler.Butler('/projects/MERIAN/repo/')
#       9 dataId = dict(tract=tract, patch=patch, band=filt)
# ---> 11 refCat = butler.get(
#      12     'deepCoadd_forced_src',
#      13     collections='DECam/runs/merian/dr1_wide',
#      14     dataId=dataId,
#      15     instrument='DECam',
#      16     skymap='hsc_rings_v1',
#      17 )[:10]#[0:8358:8357]
#      19 refExposure = butler.get(
#      20     'deepCoadd_calexp',
#      21     collections='DECam/runs/merian/dr1_wide',
#    (...)
#      24     skymap='hsc_rings_v1',
#      25 )
#      27 refCatInBand = butler.get(
#      28     'deepCoadd_ref',
#      29     collections='DECam/runs/merian/dr1_wide',
#    (...)
#      32     skymap='hsc_rings_v1',
#      33 )[:10]#[0:8358:8357]
#
# File /projects/HSC/LSST/stack_20220527/conda/envs/lsst-scipipe-4.1.0/share/eups/Linux64/daf_butler/geeb583e4b8+c02f467b15/python/lsst/daf/butler/_butler.py:1430, in Butler.get(self, datasetRefOrType, dataId, parameters, collections, storageClass, **kwargs)
#    1375 """Retrieve a stored dataset.
#    1376
#    1377 Parameters
#    (...)
#    1427 ``exposure`` is a temporal dimension.
#    1428 """
#    1429 log.debug("Butler get: %s, dataId=%s, parameters=%s", datasetRefOrType, dataId, parameters)
# -> 1430 ref = self._findDatasetRef(datasetRefOrType, dataId, collections=collections, **kwargs)
#    1431 return self.getDirect(ref, parameters=parameters, storageClass=storageClass)
#
# File /projects/HSC/LSST/stack_20220527/conda/envs/lsst-scipipe-4.1.0/share/eups/Linux64/daf_butler/geeb583e4b8+c02f467b15/python/lsst/daf/butler/_butler.py:1110, in Butler._findDatasetRef(self, datasetRefOrType, dataId, collections, allowUnresolved, **kwargs)
#    1108         if collections is None:
#    1109             collections = self.registry.defaults.collections
# -> 1110         raise LookupError(
#    1111             f"Dataset {datasetType.name} with data ID {dataId} "
#    1112             f"could not be found in collections {collections}."
#    1113         )
#    1114 if idNumber is not None and idNumber != ref.id:
#    1115     if collections is None:
#
# LookupError: Dataset deepCoadd_forced_src with data ID {band: 'i', skymap: 'hsc_rings_v1', tract: 9813, patch: 23} could not be found in collections DECam/runs/merian/dr1_wide.

# %%
np.where(refCat['parent'] == 3495901618560303105)
# Out:
# (array([], dtype=int64),)

# %% [raw]
# # Load Merian catalog as reference
# filt = 'N708'
# tract = 9813
# patch = 23
# patch_old = f'{patch % 9},{patch // 9}'
#
# import lsst.daf.butler as dafButler
# butler = dafButler.Butler('/projects/MERIAN/repo/')
# dataId = dict(tract=tract, patch=patch, band=filt)
# expID = dict(tract=tract, patch=patch, band=filt, skymap='hsc_rings_v1')
#
# # Load Merian catalog as reference
# refCat = lsst.afw.table.SourceCatalog.readFits(
#     f'/scratch/arunj/deepCoadd_forced_src_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits')
# refCatInBand = lsst.afw.table.SourceCatalog.readFits(
#     f'/scratch/arunj/deepCoadd_ref_9813_{patch}_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits')
#
# refCat = refCat[:1]
# refCatInBand = refCatInBand[:1]
#
# refExposure = lsst.afw.image.ExposureF(
#     f'/scratch/arunj/deepCoadd_calexp_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits'
# )

# %% [raw]
# # Load Merian catalog as reference
# refCat = lsst.afw.table.SourceCatalog.readFits(
#     '/scratch/arunj/deepCoadd_forced_src_9813_1_i_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits')
# # refCat = refCat[:1033]
#
# refExposure = lsst.afw.image.ExposureF(
#     "/projects/MERIAN/repo/HSC/runs/RC2/w_2022_04/DM-33402/20220128T212035Z/deepCoadd_calexp/9813/1/i/deepCoadd_calexp_9813_1_i_hsc_rings_v1_HSC_runs_RC2_w_2022_04_DM-33402_20220128T212035Z.fits")

# %%
patch
# Out:
# 23

# %%
exposure = butler.get(
    'deepCoadd_calexp',
    collections='DECam/runs/merian/dr1_wide',
    dataId=dict(tract=tract, patch=patch, band='N540'),
    instrument='DECam',
    skymap='hsc_rings_v1',
)

# %%
hsc_type = 'w04'
if hsc_type == 'w40':
    exposure = lsst.afw.image.ExposureF(
        f'/scratch/arunj/deepCoadd_calexp_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits'
    )
elif hsc_type == 'w04':
    exposure = lsst.afw.image.ExposureF(
        f"/projects/MERIAN/repo/HSC/runs/RC2/w_2022_04/DM-33402/20220128T212035Z/deepCoadd_calexp/9813/{patch}/i/deepCoadd_calexp_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_04_DM-33402_20220128T212035Z.fits"
    )
elif hsc_type == 'S20A':
    exposure = lsst.afw.image.ExposureF(
        f"/projects/MERIAN/repo/S20A/deepCoadd_calexp/9813/{patch_old}/calexp-HSC-I-{tract}-{patch_old}.fits"
    )

# %%
# exposure = lsst.afw.image.ExposureF(
#     f"/projects/MERIAN/repo/S20A/deepCoadd_calexp/9813/{patch_old}/calexp-HSC-I-{tract}-{patch_old}.fits")
# exposure = lsst.afw.image.ExposureF(
#     f'/scratch/arunj/deepCoadd_calexp_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_40_DM-36356_20221006T193226Z.fits'
# )
# exposure = lsst.afw.image.ExposureF(
#     f"/projects/MERIAN/repo/HSC/runs/RC2/w_2022_04/DM-33402/20220128T212035Z/deepCoadd_calexp/9813/{patch}/i/deepCoadd_calexp_9813_{patch}_i_hsc_rings_v1_HSC_runs_RC2_w_2022_04_DM-33402_20220128T212035Z.fits")
# exposure = lsst.afw.image.ExposureF(
#     "/projects/MERIAN/repo/DECam/runs/merian/dr1_wide/20220921T193246Z/deepCoadd_calexp/9813/79/N708/deepCoadd_calexp_9813_79_N708_hsc_rings_v1_DECam_runs_merian_dr1_wide_20220921T193246Z.fits")

# %% [markdown]
# rsync -zva --progress jiaxuanl@tiger.princeton.edu://projects/MERIAN/repo/S20A/deepCoadd_calexp/9813/5,3/calexp-HSC-I-9813-5,3.fits ./

# %%
measureConfig = lsst.meas.base.ForcedPhotCoaddConfig()
measureConfig.footprintDatasetName = 'DeblendedFlux'

# measureConfig.measurement.plugins.names.add("ext_gaap_GaapFlux")
measureConfig.measurement.plugins.names.add("base_SdssShape")
measureConfig.measurement.plugins.names.add("base_GaussianFlux")
measureConfig.measurement.plugins.names.add("base_PsfFlux")
measureConfig.measurement.plugins.names.add("base_SdssCentroid")
# measureConfig.measurement.plugins["ext_gaap_GaapFlux"].doMeasure = True  # Set it to False for timing comparison
# measureConfig.measurement.plugins["ext_gaap_GaapFlux"].doPsfPhotometry = True
# measureConfig.measurement.plugins["ext_gaap_GaapFlux"].doOptimalPhotometry = True
# measureConfig.measurement.plugins["ext_gaap_GaapFlux"].sigmas = [0.5, 0.75, 1.0, 1.5, 2.0]

photTask = lsst.meas.base.ForcedPhotCoaddTask(refSchema=refCat.schema, config=measureConfig)
photTask.log.setLevel('DEBUG')

# %%
measCat, exposureID = photTask.generateMeasCat(exposureDataId=butler.registry.expandDataId(expID), 
                                               exposure=exposure, 
                                               refCat=refCat, 
                                               refCatInBand=refCatInBand, 
                                               refWcs=refExposure.wcs, 
                                               idPackerName='tract_patch', 
                                               footprintData=refCatInBand)

# %%
print("# Starting the measureTask at ", time.ctime())
t1 = time.time()
photTask.run(measCat, exposure, refCat=refCat, refWcs=refExposure.wcs, exposureId=exposureID)
t2 = time.time()
print("# Finished measureTask in %.2f seconds." % (t2-t1))
cat2 = measCat.copy(deep=True).asAstropy()
# Out:
# # Starting the measureTask at  Tue Nov 15 16:24:09 2022
# INFO:lsst.forcedPhotCoadd.measurement:Performing forced measurement on 10 sources
# DEBUG:lsst.forcedPhotCoadd.measurement:Mask plane "THISDET" already existed
# DEBUG:lsst.forcedPhotCoadd.measurement:Mask plane "THISDET": plane 17, bitmask 131072 = 0x20000
# DEBUG:lsst.forcedPhotCoadd.measurement:Mask plane "OTHERDET" already existed
# DEBUG:lsst.forcedPhotCoadd.measurement:Mask plane "OTHERDET": plane 18, bitmask 262144 = 0x40000
# DEBUG:lsst.forcedPhotCoadd.measurement:Measured from image: clipped mean = 0.00539747, stdev = 0.0238513
# DEBUG:lsst.forcedPhotCoadd.measurement:Using noise generator: FixedGaussianNoiseGenerator: mean=0.00539747, std=0.0238513
# DEBUG:lsst.forcedPhotCoadd.measurement.base_GaussianFlux:MeasurementError in base_GaussianFlux.measure on record 3495901618560303108:
#   File "src/InputUtilities.cc", line 179, in lsst::afw::geom::ellipses::Quadrupole lsst::meas::base::SafeShapeExtractor::operator()(lsst::afw::table::SourceRecord&, const lsst::meas::base::FlagHandler&) const
#     base_GaussianFlux: Shape needed, and Shape slot measurement failed. {0}
# lsst::meas::base::MeasurementError: 'base_GaussianFlux: Shape needed, and Shape slot measurement failed.'
#
# DEBUG:lsst.forcedPhotCoadd.measurement.base_Variance:MeasurementError in base_Variance.measure on record 3495901618560303108: Footprint empty, or all pixels are masked, can't compute median
# DEBUG:lsst.forcedPhotCoadd.measurement.base_GaussianFlux:MeasurementError in base_GaussianFlux.measure on record 3495901618560303111:
#   File "src/InputUtilities.cc", line 179, in lsst::afw::geom::ellipses::Quadrupole lsst::meas::base::SafeShapeExtractor::operator()(lsst::afw::table::SourceRecord&, const lsst::meas::base::FlagHandler&) const
#     base_GaussianFlux: Shape needed, and Shape slot measurement failed. {0}
# lsst::meas::base::MeasurementError: 'base_GaussianFlux: Shape needed, and Shape slot measurement failed.'
#
# DEBUG:lsst.forcedPhotCoadd.measurement.base_Variance:MeasurementError in base_Variance.measure on record 3495901618560303111: Footprint empty, or all pixels are masked, can't compute median
# DEBUG:lsst.forcedPhotCoadd.measurement.base_GaussianFlux:MeasurementError in base_GaussianFlux.measure on record 3495901618560303113:
#   File "src/InputUtilities.cc", line 179, in lsst::afw::geom::ellipses::Quadrupole lsst::meas::base::SafeShapeExtractor::operator()(lsst::afw::table::SourceRecord&, const lsst::meas::base::FlagHandler&) const
#     base_GaussianFlux: Shape needed, and Shape slot measurement failed. {0}
# lsst::meas::base::MeasurementError: 'base_GaussianFlux: Shape needed, and Shape slot measurement failed.'
#
# DEBUG:lsst.forcedPhotCoadd.measurement.base_Variance:MeasurementError in base_Variance.measure on record 3495901618560303113: Footprint empty, or all pixels are masked, can't compute median
# DEBUG:lsst.forcedPhotCoadd.measurement.base_PsfFlux:Exception in base_PsfFlux.measure on record 3495901618560303116:
#   File "src/PsfFlux.cc", line 120, in virtual void lsst::meas::base::PsfFluxAlgorithm::measure(lsst::afw::table::SourceRecord&, const lsst::afw::image::Exposure<float>&) const
#     Invalid pixel value detected in image. {0}
# lsst::meas::base::PixelValueError: 'Invalid pixel value detected in image.'
#
# INFO:lsst.forcedPhotCoadd.applyApCorr:Applying aperture corrections to 2 instFlux fields
# DEBUG:lsst.forcedPhotCoadd.applyApCorr:Use naive instFlux sigma computation
# DEBUG:lsst.forcedPhotCoadd.applyApCorr:For instFlux field 'base_GaussianFlux': mean apCorr=1.1757541873534059, stdDev apCorr=0.0019556997750599203, mean apCorrErr=0.0, stdDev apCorrErr=0.0 for 10 sources
# DEBUG:lsst.forcedPhotCoadd.applyApCorr:For instFlux field 'base_PsfFlux': mean apCorr=0.9825489058063781, stdDev apCorr=0.0025886732476423737, mean apCorrErr=0.0, stdDev apCorrErr=0.0 for 10 sources
# # Finished measureTask in 1.86 seconds.

# %%
exposure.maskedImage.image.array
# Out:
# array([[-0.00478826, -0.02366047,  0.01351222, ..., -0.02213353,
#         -0.01999103, -0.03397224],
#        [-0.07917799,  0.00301284,  0.01874887, ...,  0.03707562,
#          0.00403379, -0.00918899],
#        [ 0.00412722, -0.03419884,  0.01729096, ...,  0.04336281,
#          0.00776215, -0.00139005],
#        ...,
#        [ 0.01711968, -0.02333547,  0.01931767, ...,  0.00319285,
#         -0.04415698, -0.02653152],
#        [-0.01441645, -0.00234833, -0.01048884, ...,  0.00803461,
#          0.00761188,  0.00841603],
#        [ 0.01571479,  0.00181556, -0.02700768, ...,  0.00465566,
#         -0.01651617,  0.00281824]], dtype=float32)

# %%
refCat['id'] == 3495901618560303105
# Out:
# array([ True, False, False, False, False, False, False, False, False])

# %%
## Now it's using Merian footprints on RC2 w40.

# %%
def writeObjectTable(measCat, band='i', save=True):
    import astropy.units as u
    from astropy.table import QTable
    
    outCat = measCat.copy(deep=True).asAstropy()
    outCat['coord_ra'] = outCat['coord_ra'].to(u.deg)
    outCat['coord_dec'] = outCat['coord_dec'].to(u.deg)

    old_gaap_cols = [
        item for item in measCat.schema.getNames() if ('gaap' in item and 'apCorr' not in item) | ('base_PsfFlux_instFlux' in item) | ('base_CircularApertureFlux' in item)]
    outCat = outCat[['id', 'coord_ra', 'coord_dec'] + old_gaap_cols]
    
    # PhotCalib
    for col in old_gaap_cols:
        if 'instFlux' in col:
            outCat[col] = outCat[col].value * \
                exposure.getPhotoCalib().instFluxToNanojansky(1) * u.nanomaggy

    new_gaap_cols = []
    for col in old_gaap_cols:
        name = col.replace('ext_gaap_GaapFlux', f'{band}_gaap')
        name = name.replace('_instFlux', 'Flux').replace('PsfFlux', 'Psf')
        if 'Flux' in name:
            aper = name.split(
                "x_")[-1].replace('FluxErr', '').replace('Flux', '')
            name = name.replace('_1_15x', '')
            name = name.replace('_' + aper, aper.replace('_', 'p'))

        if 'flag' in name:
            aper = name.split(
                "x_")[-1].replace('_flag_bigPsf', '').replace('_flag', '')
            name = name.replace('_1_15x', '')
            if not 'gauss' in name:
                name = name.replace(
                    '_' + aper, aper.replace('_', 'p') + 'Flux')
        new_gaap_cols.append(name)
    
    outCat.rename_columns(old_gaap_cols, new_gaap_cols)
    outCat = QTable(outCat)
    return outCat

# %%
import sys
sys.path.append('/home/jiaxuanl/Research/Merian/merian_tractor/scripts/')

# %%
from hsc_gaap.gaap import joinMerianCatPatches
cat2 = writeObjectTable(measCat, band='i')
cat2.remove_columns(['id', 'coord_ra', 'coord_dec'])
cat_ref = joinMerianCatPatches([23])

# %%
cat = hstack([cat_ref, cat2])

# %%
flag = (cat['deblend_nChild'] > 0)

# %%
plt.scatter(30 - 2.5 * np.log10(cat[flag]['i_gaap1p0Flux'].data), 
            -2.5 * np.log10(cat[flag]['i_gaap1p0Flux'].data / cat[flag]['N708_gaap1p0Flux']), 
            s=1, label='Parents')

plt.scatter(30 - 2.5 * np.log10(cat[~flag]['i_gaap1p0Flux'].data), 
            -2.5 * np.log10(cat[~flag]['i_gaap1p0Flux'].data / cat[~flag]['N708_gaap1p0Flux']), 
            s=1, alpha=0.2, label='Children')

plt.xlim(15, 27)
plt.ylim(-0.5, 0.5)
leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)
plt.xlabel('i mag, manual')
plt.ylabel('i - N708')
plt.title('ref=Merian, img=HSC RC2 w40')
# Out:
# Text(0.5, 1.0, 'ref=Merian, img=HSC RC2 w40')

# %%
plt.scatter(30 - 2.5 * np.log10(cat[flag]['base_PsfFlux'].data), 
            -2.5 * np.log10(cat[flag]['base_PsfFlux'].data / cat[flag]['N708_psfFlux']), 
            s=1, label='Parents')

plt.scatter(30 - 2.5 * np.log10(cat[~flag]['base_PsfFlux'].data), 
            -2.5 * np.log10(cat[~flag]['base_PsfFlux'].data / cat[~flag]['N708_psfFlux']), 
            s=1, alpha=0.2, label='Children')

plt.xlim(15, 27)
plt.ylim(-1, 1)
leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)
plt.xlabel('i mag, manual')
plt.ylabel('i - N708')
plt.title('ref=Merian, img=HSC RC2 w40')
# Out:
# Text(0.5, 1.0, 'ref=Merian, img=HSC RC2 w40')

# %%
cat['N708_psfFlux']

# %%
10**(0.4 * 0.07)
# Out:
# 1.066596121230258

# %%
photTask.log.name
# Out:
# 'lsst.forcedPhotCoadd'

# %% [markdown]
# rsync -zva --progress jiaxuanl@tiger.princeton.edu://projects/MERIAN/repo/S20A/gaapTable/9813/gaap_9813_23_Merian_RC2_i.fits ./

# %%
cat = hstack([cat_ref, cat2])
cat.write('/projects/MERIAN/repo/S20A/gaapTable/9813/gaap_9813_23_Merian_RC2_i.fits')

# %%
fig, ax = plt.subplots(figsize=(6, 4))

mag = 30 - 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data * 57.543993733715425)
diff = - 2.5 * np.log10(cat2['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data) + 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data)
plt.scatter(mag, 
            diff,
            s=1)

plt.xlim(16, 25)
# plt.ylim(-0.5, 0.5)
# plt.ylim(-0.2, 0.2)

plt.axhline(0, color='k', ls='--')

plt.xlabel('i mag')
plt.ylabel('Delta(i), manual - RC2')

# %%
fig, ax = plt.subplots(figsize=(6, 4))

mag = 30 - 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data * 57.543993733715425)
diff = - 2.5 * np.log10(cat2['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data) + 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data)
plt.scatter(mag, 
            diff,
            s=1)

plt.xlim(16, 25)
# plt.ylim(-0.5, 0.5)
# plt.ylim(-0.2, 0.2)

plt.axhline(0, color='k', ls='--')

plt.xlabel('i mag')
plt.ylabel('Delta(i), manual - RC2')
# Out:
# Text(0, 0.5, 'Delta(i), manual - RC2')

# %%
fig, ax = plt.subplots(figsize=(6, 4))

mag = 30 - 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data * 57.543993733715425)
diff = - 2.5 * np.log10(cat2['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data) + 2.5 * np.log10(refCat.asAstropy()['ext_gaap_GaapFlux_1_15x_1_0_instFlux'].data)
plt.scatter(mag, 
            diff,
            s=1)

# plt.xlim(20, 29)
plt.ylim(-0.1, 0.1)

plt.axhline(0, color='k', ls='--')

plt.xlabel('i mag')
plt.ylabel('Delta(i), manual - RC2')
# Out:
# Text(0, 0.5, 'Delta(i), manual - RC2')

# %%
import lsst.afw.display as afwDisplay
import lsst.afw.geom as afwGeom

# %%
recordId = 0
shape = refCat[recordId].getShape()
shape
# Out:
# Quadrupole(ixx=22.467348068135465, iyy=32.38096968264305, ixy=7.092387580840181)

# %%
afwDisplay.setDefaultBackend('matplotlib')
fig, ax = plt.subplots(figsize=(10, 10))
display = afwDisplay.Display(frame=fig)
display.scale("linear", "zscale")
display.setMaskTransparency(80)

obj = refCatInBand[recordId]
footprint = obj.getFootprint()
bbox = footprint.getBBox()
cutout = exposure[bbox]
display.mtv(cutout)
display.dot(shape, *obj.getCentroid()) #*bbox.getCenter())
# ax[1].set_title(f"recordId = {recordId}")

# %%
display.mtv??

# %%
afwDisplay.setDefaultBackend('matplotlib')
fig, ax = plt.subplots(figsize=(10, 10))
display = afwDisplay.Display(frame=fig)
display.scale("linear", "zscale")
display.setMaskTransparency(80)

obj = refCatInBand[recordId]
footprint = obj.getFootprint()
bbox = footprint.getBBox()
cutout = refExposure[bbox]
display.mtv(cutout)
display.dot(shape, *obj.getCentroid()) #*bbox.getCenter())
# ax[1].set_title(f"recordId = {recordId}")
